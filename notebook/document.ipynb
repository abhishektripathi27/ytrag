# %% [markdown]
# <b>Data Ingestion</b>

# %%
### Document Structure

from langchain_core.documents import Document

# %%
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
### TextLoader
from langchain.document_loaders import  TextLoader
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its readability and simplicity. It was created by Guido van Rossum and first released in 1991.\n\nKey Features:\n- Easy-to-read syntax\n- Dynamic typing\n- Large standard library\n- Cross-platform support\n- Strong community ecosystem\n\nPython is widely used in:\n- Web development\n- Data engineering\n- Data analysis\n- Artificial intelligence\n- Machine learning\n- Automation and scripting\n\nExample Python Code:\n\ndef greet(name):\n    return f"Hello, {name}!"\n\nmessage = greet("World")\nprint(message)\n\nPython supports multiple programming paradigms including procedural, object-oriented, and functional programming.\n\nPopular Python libraries include:\n- NumPy for numerical computing\n- Pandas for data manipulation\n- Matplotlib for visualization\n- Requests for HTTP communication\n- FastAPI for web APIs\n\nPython has become one of the most popular programming languages because it enables rapid development and has a low learning curve.')]

# %%
##Directory Loader
from langchain_community.document_loaders import DirectoryLoader

##load all the text files from the directory

dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls= TextLoader,
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False                                    
)

docuemnts = dir_loader.load()
docuemnts
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its readability and simplicity. It was created by Guido van Rossum and first released in 1991.\n\nKey Features:\n- Easy-to-read syntax\n- Dynamic typing\n- Large standard library\n- Cross-platform support\n- Strong community ecosystem\n\nPython is widely used in:\n- Web development\n- Data engineering\n- Data analysis\n- Artificial intelligence\n- Machine learning\n- Automation and scripting\n\nExample Python Code:\n\ndef greet(name):\n    return f"Hello, {name}!"\n\nmessage = greet("World")\nprint(message)\n\nPython supports multiple programming paradigms including procedural, object-oriented, and functional programming.\n\nPopular Python libraries include:\n- NumPy for numerical computing\n- Pandas for data manipulation\n- Matplotlib for visualization\n- Requests for HTTP communication\n- FastAPI for web APIs\n\nPython has become one of the most popular programming languages because it enables rapid development and has a low learning curve.'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Fundamentals\n\nMachine Learning (ML) is a branch of artificial intelligence that enables computers to learn patterns from data and make predictions without being explicitly programmed for every task.\n\nMajor Types of Machine Learning:\n\n1. Supervised Learning\n   - Uses labeled training data\n   - Examples: classification and regression\n   - Algorithms:\n     - Linear Regression\n     - Logistic Regression\n     - Random Forest\n     - Support Vector Machines\n\n2. Unsupervised Learning\n   - Uses unlabeled data\n   - Discovers hidden patterns\n   - Algorithms:\n     - K-Means Clustering\n     - Hierarchical Clustering\n     - Principal Component Analysis (PCA)\n\n3. Reinforcement Learning\n   - Learns through rewards and penalties\n   - Commonly used in robotics and game playing\n\nTypical Machine Learning Workflow:\n1. Collect data\n2. Clean and preprocess data\n3. Split data into training and testing sets\n4. Train a model\n5. Evaluate model performance\n6. Deploy the model\n7. Monitor and retrain as needed\n\nCommon Evaluation Metrics:\n- Accuracy\n- Precision\n- Recall\n- F1 Score\n- ROC-AUC\n\nPopular ML Libraries:\n- Scikit-learn\n- TensorFlow\n- PyTorch\n- XGBoost\n\nMachine learning is widely used in recommendation systems, fraud detection, natural language processing, computer vision, and predictive analytics.')]

# %%
##Directory Loader pdf
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

##load all the text files from the directory

dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls= PyMuPDFLoader,
    #loader_kwargs={'encoding': 'utf-8'},
    show_progress=False                                    
)

pdf_docuemnts = dir_loader.load()
pdf_docuemnts
# Out:
# [Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-04-21T14:12:01+03:00', 'source': '../data/pdf/Tech Volume - Final Draft.pdf', 'file_path': '../data/pdf/Tech Volume - Final Draft.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'Lexi Czulewicz', 'subject': '', 'keywords': '', 'moddate': '2025-04-21T14:12:01+03:00', 'trapped': '', 'modDate': "D:20250421141201+03'00'", 'creationDate': "D:20250421141201+03'00'", 'page': 0}, page_content='Web3 Tech \nA254-024 \nA254-024-1134 \n1 \n \nVolume 2: Technical Volume \nIntroduction \nWeb3 Tech’s AI-Powered Context Aware Military Decision Support System addresses the challenge of \ninformation overload for Commanders by transforming diverse data streams into actionable insights. The \nsystem integrates information from various sources, using military-adapted Large Language Models (LLMs) \nand knowledge graphs to analyze and map battlefield data. This analysis is presented through an intuitive \ndashboard, designed to function even in contested environments. Web3 Tech has experience delivering \nsimilar technologies for Fortune 500 companies, demonstrating real-time data integration and summarization \ncapabilities. The next steps involve enhancing interoperability and refining the User Interface to create a fully \noperational prototype. This system will enable Commanders to efficiently process more information, \nenhancing situational awareness and accelerating decision cycles, thereby improving operational outcomes \nwhile reducing cognitive load. \nArmy Benefits \nMilitary commanders face the challenge of processing vast amounts of data from diverse sources, creating a \nhigh cognitive load and hindering effective decision-making. Web3 Tech’s AI-Powered Context Aware Military \nDecision Support System addresses this problem by providing real-time, context-aware decision support. The \nsystem synthesizes mission-relevant data from various sources, presenting prioritized, actionable intelligence \nthrough an intuitive dashboard designed for high-stress military situations. This enhances situational \nawareness, accelerates decision cycles, and reduces cognitive load. \nThe integrated architecture delivers secure, scalable integration of diverse military data, meeting evolving \nmission demands without compromising performance. It enables secure cross-domain data sharing and is \noptimized for bandwidth-constrained environments through adaptive streaming and data compression. \nOffline capabilities ensure access to critical information even in challenging operational conditions, improving \nresilience and reliability. Seamless integration with the Azure Government Cloud provides additional security \nand compliance benefits. \nGiven the demanding nature of military operations, the system offers crucial capabilities for complex \nenvironments like Syria, where situational awareness and informed decision-making are essential for mission \nsuccess and soldier safety. Its offline capabilities ensure commanders can navigate challenges and respond \nswiftly to emerging threats, preparing the Army for rapidly-changing environments. \nTechnical Approach \nThe AI-Powered Context Aware Decision Support System will consist of two main components: an Offline \nModel Training component and a Live Application component. The Offline Model Training component will \ninclude a Data Ingestion and Processing Layer and a Model Training Hub, while the Live Application component \nwill feature an Intelligence Layer, an Agentic Decision-Making Layer, and a User Interface. To protect sensitive \noperational data, the system will employ comprehensive security measures such as classification \nenforcement, zero-trust architecture, military-grade cryptography, and AI-specific protections. Utilizing the \nAzure Government and Databricks platform, which offers FedRAMP High/IL5 compliance, customer-managed \nenc ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-04-21T14:12:01+03:00', 'source': '../data/pdf/Tech Volume - Final Draft.pdf', 'file_path': '../data/pdf/Tech Volume - Final Draft.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'Lexi Czulewicz', 'subject': '', 'keywords': '', 'moddate': '2025-04-21T14:12:01+03:00', 'trapped': '', 'modDate': "D:20250421141201+03'00'", 'creationDate': "D:20250421141201+03'00'", 'page': 1}, page_content='Web3 Tech \nA254-024 \nA254-024-1134 \n2 \n \n \nAI-Powered Context Aware Military Decision Support System \nData Ingestion & Processing Layer. This layer is a cloud-native, secure data integration framework leveraging \nAzure technologies to ingest and standardize information from various military sources. It unifies Operational, \nTraining, and Historical Mission Data with enterprise-grade scalability and intelligence. The framework \nensures data classification, tracking, and management using automated tools to maintain quality and \ncompliance. Key components include Data Ingestion and Connectivity, Data Transformation and \nStandardization, and a Multi-Tiered Storage Architecture. Cutting-edge security measures protect data during \ncollection, storage, and transfer. \n● \nData Ingestion and Connectivity. Operational Data from sensors and systems will be captured and \nprocessed in real-time. Training Data from simulation exercises and wearable devices will be collected \nand stored for performance analysis. Historical Mission Data will also be retrieved, organized, and stored \nsecurely allowing it to be analyzed alongside new information. Visual Data, such as maps and images from \nsoldiers on the ground will be captured via secure mobile devices or drones and processed using Azure’s \ncomputer vision and geospatial analysis tools. Custom connectors will allow the system to be integrated \nwith operational systems, ensuring compatibility with diverse formats and protocols. \n● \nData Transformation and Standardization. The system will organize data from different sources into a \ncommon format for easy analysis and comparison. Real-time data will help detect potential threats, while \nTraining Data will track trends and readiness over time. Historical Data will be enriched with tags and \nmetadata for better context. \n● \nMulti-Tiered Storage Architecture. Data will be stored based on its type and usage. Data that is \nfrequently accessed will be kept readily available, while older, less-used data is archived to save costs. \nThe system will ensure that data is globally accessible while remaining secure. \nModel Training Hub. The Model Training Hub will handle various input types, including continuous, time \nseries, and unstructured data. It will train multiple models, such as decision trees, classification models, and \nneural networks, to produce outcomes like event likelihood, numeric forecasts, or recommendations. Periodic \ntraining and recalibration will ensure models are updated with new data sources. Once tested, the updated \nmodel will replace the existing live model. These models will operate in the Intelligence layer to respond to \nuser queries. \nIntelligence Layer. This layer will use pre-trained models to convert raw data into summarized information. \nModels include those from the Model Training Hub and specialized Large Language Models (LLMs) for military \npurposes, such as COA-GPT and SmartBook. All models will be live and online. A Routing Agent will route user \nqueries to the appropriate model, which will generate a response. The Response Calibration Agent will \nsummarize the output before presenting it to the user. In the future, Web3 Tech aims to enhance this system \nby routing a single user query to both an LLM and a Machine Learning (ML) model. The outputs from both \nmodels would then be combined into a unified response for the user.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-04-21T14:12:01+03:00', 'source': '../data/pdf/Tech Volume - Final Draft.pdf', 'file_path': '../data/pdf/Tech Volume - Final Draft.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'Lexi Czulewicz', 'subject': '', 'keywords': '', 'moddate': '2025-04-21T14:12:01+03:00', 'trapped': '', 'modDate': "D:20250421141201+03'00'", 'creationDate': "D:20250421141201+03'00'", 'page': 2}, page_content='Web3 Tech \nA254-024 \nA254-024-1134 \n3 \n \nAgentic Layer. The Agentic Layer will utilize a multi-agent framework to synthesize analyses into context-\naware, prioritized, actionable intelligence. It will consist of multiple agents, each trained towards a defined \ntask. \n● \nRAG. Retrieval augmented generation (RAG) is a way to augment the user prompts with additional and \ncontextual information from the vector database. Vector database consists of vectorized information in \nnumerical form. Embedding models are used to translate the user query to similar vectors thus enabling \nenrichment of the original prompts with additional pertinent information. These enriched prompts are sent \nto the LLM via Routing agent. \n● \nRouting Agent. This agent will be responsible for interpreting user queries and routing them to the right \nModel or LLM. The decision logic will be based on the type of data and associated queries, which will \ndetermine the model best suited for the task. This agent will be trained with the history of user queries and \nthe models chosen to handle the respective queries. \n● \nResponse Calibration Agent. This agent will convert Model results into concise responses for the user. \nThe output can be a text recommendation, chart, or table, depending on the most efficient way to \nrepresent the response. This process will add sophistication and differentiation to the system. The Agent \nwill continuously learn and improve based on user feedback, using the hierarchical learning approach \nReinforcement Learning through Human Feedback (RLHF). This approach will be extended to implement \nExplainable AI framework. Multiple Agents will coordinate and compete with each other to provide the best \noutcomes, guided by user inputs. These user inputs will then serve as learning feedback, helping the Agent \nto continue to improve over time. \n● \nContext Management Agent with Prompt Engineering. This agent will be responsible for recognizing the \ncontext of user queries. Context will be derived from user inputs, ongoing conversations, or explicit user \ninformation. Tags will be generated for the context, which the Agent will interpret, maintain, and update. \nThis will enable the Agent to keep track of conversation and conversation history as well as maintain \nawareness of the user’s environment. Prompt Engineering will use these context tags to create context-\naware prompts for the LLMs and calibrate the response. \nUser Interface and Feedback Layer. This layer will act as a command center to generate context-aware \nrecommendations with situational awareness. It will feature a customized User Interface to submit queries \nalong with input parameters. Designed in an interactive format, it will collect user inputs to fine-tune the \nAgentic Layer’s operations. The calibrated outputs will be displayed on the User Interface, allowing users to \nextend conversations, adjust outputs, and provide feedback, which will instantly inform the Agentic Layer. \nWhile simplicity and efficiency will be prioritized, users can choose to tune and request a recalibrated output \nwith increased details and complexity. \nEnabling Technologies \nThe technologies selected for this solution—Azure Cloud, Databricks, and state-of-the-art AI frameworks like \nCOA-GPT, SmartBook, LangChain, and OpenAI—are proven in large-scale, secure enterprise and government \nenvironments. For instance, the US Army  ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-04-21T14:12:01+03:00', 'source': '../data/pdf/Tech Volume - Final Draft.pdf', 'file_path': '../data/pdf/Tech Volume - Final Draft.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'Lexi Czulewicz', 'subject': '', 'keywords': '', 'moddate': '2025-04-21T14:12:01+03:00', 'trapped': '', 'modDate': "D:20250421141201+03'00'", 'creationDate': "D:20250421141201+03'00'", 'page': 3}, page_content='Web3 Tech \nA254-024 \nA254-024-1134 \n4 \n \nthe Army Health System Doctrine Smart Book provide comprehensive overviews of military doctrine. \nLangChain is instrumental in building applications on top of Large Language Models (LLMs), enhancing their \nfunctionality. Open AI’s tools, including ChatGPT, are now permitted for military use and have been integrated \ninto the Army’s cloud services infrastructure. Generative AI (GenAI) models are deployed in key operations \nsuch as battlefield intelligence and logistics forecasting. Together, these components, combined with \nDevSecOps practices and explainable AI layers, form a modular stack capable of operating in real-time within \ncomplex military environments. \nTechnical Team \nVikram Vala, CEO & Primary Investigator. With over 20 years of experience delivering E-Commerce and Billing \nSolutions for Fortune 100 companies and leading IT projects. He holds an MS in Technology Management from \nColumbia University and an MS in Computer Science from South Gujarat University. He specializes in AI, \nScalability, Cloud Computing, Data Analytics, and Digital Transformation, always leveraging the latest \ntechnologies. His expertise spans multiple industries, including retail, healthcare, and telecommunications. \nHe has worked for successful technology companies like Salesforce, IBM, Oracle, and managed programs for \nreputable brands like Walgreens, GSK, Dow Corning, Vodafone, and Southwest Airlines. \nAbhishek Tripathi, Lead Data Architect. An experienced data architect with over 20 years in ETL, Data \nWarehousing, and Business Intelligence. He holds certifications from AWS, Azure, and Databricks, a BE in \nMechanical Engineering from Bhilai Institute of Technology, and an MS in Computer Science from Bradley \nUniversity. He has led projects across various industries, working with major clients such as United Airlines, \nWalgreens, Motorola, and Fidelity Investments. \nMayur Sedani, Lead Data Scientist. Skilled analytics professional with over 20 years of expertise in \necommerce product optimization, data science solutions for FinTech, and market optimization. He holds an \nMS in Industrial Engineering from the University of South Florida. He has technical proficiency in programming \ntools like Python, Spark, and SQL, along with software such as Tableau and Power BI, as well as Azure Delta \nLake, Databricks, and other Database and Cloud software. \nDRS IT Solutions: A leading provider of Information Technology Staffing and Recruitment services specialized \nin sourcing Emerging Technologies. Core competencies include Big Data, Analytics, AI, Machine Learning, \nCloud Computing, and Blockchain. They serve a wide range of industries such as finance, healthcare, logistics, \nand telecommunications. Their rigorous screening process and comprehensive testing set them apart from \nothers in the industry. \nTechnical Risks & Mitigation Plans \nTo mitigate data integration complexity, a phased approach will start with three to four high-value data \nsources. An adapter-based architecture will enable quick connections to various data formats. Synthetic data \nwill be used during early development to reduce reliance on source systems. Early partnerships with military \nIT personnel will provide valuable insights and support. Data profiling and cleansing pipelines will address data \ncompleteness and quality. Data quality rules will ensure consiste ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-04-21T14:12:01+03:00', 'source': '../data/pdf/Tech Volume - Final Draft.pdf', 'file_path': '../data/pdf/Tech Volume - Final Draft.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'Lexi Czulewicz', 'subject': '', 'keywords': '', 'moddate': '2025-04-21T14:12:01+03:00', 'trapped': '', 'modDate': "D:20250421141201+03'00'", 'creationDate': "D:20250421141201+03'00'", 'page': 4}, page_content='Web3 Tech \nA254-024 \nA254-024-1134 \n5 \n \nProgrammatic Potential \nKey Milestones & Deliverables Timeline \nAward + 1 Month – Finalize Requirements & Set up Infrastructure \nData Engineering – Abhishek Tripathi \nIdentify and catalog priority Army data sources, assess data formats, and design an integration architecture. \nProvision a secure Azure Government and Databricks development environment, configure security \ncontrols, and implement a CI/CD pipeline. \nDeliverables: A Data Integration Architecture report and templates for the functional development \nenvironment including a working pipeline for at least two data source types. \nData Science – Mayur Sedani \nAdapt foundation models to the military context, design an evaluation methodology, and create prompt \nengineering templates. Define specialized agent types for Army use cases and design agent interaction \npatterns. \nDeliverables: A Military AI Adaptation Strategy report with an Agent Architecture blueprint to guide the \nadaptation of AI models to the Army and describe the architecture for specialized agents designed for Army \nuse cases. \nFront End: Vikram Vala \nAnalyze existing Army command interfaces, conduct user interviews, and define information hierarchy and \nvisualization requirements. Develop low-fidelity wireframes and a clickable prototype. \nDeliverables: A User Interface Requirements report and the Interactive User Interface Prototype will be \nprovided, outlining the specifications and functionalities of the User Interface. \nAward + 2 Months – Core Components Development \nData Engineering – Abhishek Tripathi & DRS IT Systems \nDesign scalable, cloud-native data pipelines, and develop automated data mapping and schema \nharmonization routines. \nDeliverable: Results from testing demonstration of functioning data pipelines. \nData Science – Vikram Vala, Mayur Sedani, and DRS IT Systems \nFine-tune foundation models with military-specific datasets, implement Retrieval-Augmented Generation \n(RAG) capabilities, and develop a context-aware prompt engineering system. \nDeliverables: A report detailing the Customized Foundation Model for military use along with test results \nshowing the functionality of the pattern detection engine. \nFront End – Vikram Vala, Mayur Sedani, and DRS IT Systems \nImplement core dashboard components and develop adaptive information displays. Develop a \nCommander query interpretation module and a context-aware conversation management system. \nDeliverables: Demonstration of a working dashboard prototype with dynamic components and a report \ndetailing the functionality of the natural language interface. \nAward + 3 Months – Integration and Feature Enhancements \nData Engineering: Abhishek Tripathi and DRS IT Systems \nDevelop streaming data pipelines and an event-driven architecture. Implement cross-source entity \nresolution and data lineage tracking. \nDeliverables: A report showcasing an enhanced Data Integration Layer and real-time data processing \nframework. \nData Science: Vikram Vala, Mayur Sedani, and DRS IT Systems \nDevelop an agent orchestration system, a context-aware recommendation generation system, and an \nexplanation generation system. \nDeliverables: A report with a detailed overview of the functioning multi-agent system with collaborative \nproblem-solving capabilities along with an in-depth description of the completed insight generation system. \nFront End  ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-04-21T14:12:01+03:00', 'source': '../data/pdf/Tech Volume - Final Draft.pdf', 'file_path': '../data/pdf/Tech Volume - Final Draft.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'Lexi Czulewicz', 'subject': '', 'keywords': '', 'moddate': '2025-04-21T14:12:01+03:00', 'trapped': '', 'modDate': "D:20250421141201+03'00'", 'creationDate': "D:20250421141201+03'00'", 'page': 5}, page_content="Web3 Tech \nA254-024 \nA254-024-1134 \n6 \n \nAward + 4 Months – System Integration \nData Engineering - Abhishek Tripathi and DRS IT Systems \nImplement a cross-domain data transfer mechanism and develop integration connectors for the existing \nsystem. \nDeliverables: A report detailing the cross-domain architecture and results of testing showing the working \nconnections of the Enterprise Integration framework. \nData Science - Mayur Sedani and DRS IT Systems \nDevelop predictive models, build scenario modeling capabilities, and implement a context-sensitive \nresponse generation system. \nDeliverables: A report detailing the predictive analytics suite and the capabilities of the adaptive system, \nincluding context-sensitive, role-specific responses. \nFront End & Dashboard Development – Vikram Vala, Mayur Sedani, and DRS IT Systems \nDevelop role-based views and access controls, implement shared operational pictures, and develop a high \npriority-based alerting framework. \nDeliverables: A report will be provided that details the capabilities of the User Interface in supporting \nmultiple role-appropriate views. In addition, results from testing of the intelligent notification system. \nAward + 5 Months – Performance Optimization & System Testing \nData Engineering – Abhishek Tripathi and DRS IT Systems \nImplement performance tuning for data pipelines, create load balancing for distributed processing, and \nimplement comprehensive data quality validation. \nDeliverable: An optimized data load report with pre- and post- optimization along with data quality reports. \nData Science - Mayur Sedani and DRS IT Systems \nOptimize model performance, develop an explanation generation system, and build decision audit trails. \nDeliverables: A hardened AI model report with pre- and post- optimization along with an explainability \nreport that demonstrates a clear reasoning chain will be provided. \nFront End Development & Quality Assurance (QA) - Vik Vikram & DRS IT Systems \nImplement improvements to the User Interface and Operational Dashboard based on System Testing \nreports. \nDeliverables: A System Testing Report detailing the tests conducting and the corresponding results. \nAward + 6 Months - Final Validation and Transition to Phase II \nData Engineering – Abhishek Tripathi \nValidate the final Data Integration pipeline. \nDeliverable: \nA validation report confirming pipeline functionality will be provided. \nData Science - Mayur Sedani \nValidate and benchmark the final model, compare AI performance to a human analyst baseline, and \ncontinuously monitor and assess the model's performance. \nDeliverable: A validation report comparing AI performance to a human analyst baseline across multiple \nscenarios. \nFinal QA & Transition Preparation – Vikram Vala \n Implement final visual refinements, develop demonstrations of key capabilities, and execute end-to-end \nquality assurance. \nDeliverable: A final QA report along with a detailed Phase II Transition Strategy. \nArmy Transition Pathway \nPhase I: Aligning with the Defense Sector (6-12 months). The primary goal of Phase I is to establish the \ntechnical and commercial feasibility by delivering a proof-of-concept model that demonstrates real-time \nintegration and summarization of mission-relevant data. This phase will focus on securing the initial SBIR \nPhase I award for this proof-of-concept model, developing 2-3 targeted use cases  ...
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-04-21T14:12:01+03:00', 'source': '../data/pdf/Tech Volume - Final Draft.pdf', 'file_path': '../data/pdf/Tech Volume - Final Draft.pdf', 'total_pages': 7, 'format': 'PDF 1.7', 'title': '', 'author': 'Lexi Czulewicz', 'subject': '', 'keywords': '', 'moddate': '2025-04-21T14:12:01+03:00', 'trapped': '', 'modDate': "D:20250421141201+03'00'", 'creationDate': "D:20250421141201+03'00'", 'page': 6}, page_content="Web3 Tech \nA254-024 \nA254-024-1134 \n7 \n \ndomain expertise, developing modular components that can be deployed across multiple military use cases, \nand pursuing complementary defense contracts leveraging established relationships. \nPhase III: Commercial Adaptation (24-36 months). The final phase will focus on packaging the core \ntechnology for high-value industry sectors such as healthcare, finance, and energy. This phase will aim to \nestablish recurring revenue through a subscription/SaaS model, build indirect sales channels through \ntechnology partnerships, and consider venture funding for accelerated growth after proven defense traction. \nArmy Customer Discovery and Validation \nWeb3 Tech is preparing for tech showcases and a pitch event for the AFWERX program to demonstrate their \nAI-Powered Context Aware Military Decision Support System. These events will allow them to engage with \nArmy Stakeholders, facilitating customer discovery and feedback opportunities. More details on the team's \nexperience and approach to customer discovery validation are in the Commercialization Potential section. \nCommercialization Potential \nThe Web3 Tech team has over 70 years of combined experience in designing and delivering data-intensive, AI-\nspecific, and enterprise digital transformation for Fortune 500 companies like Walgreens, Caterpillar, United \nAirlines, JP Morgan Chase, GE Capital, Wells Fargo, Chamberlain, Vodafone, and Dow Corning. They have \nsuccessfully implemented secure, scalable data pipelines to ingest and process multi-modal inputs, including \nbattlefield telemetry, ISR feeds, intelligence reports, and readiness metrics. \nWhile the complete integrated solution is not yet implemented, the team has leveraged their experience to \nengage in customer discovery with Army stakeholders. Their approach combines commercial best practices \nfrom Fortune 500 implementations with military-specific requirements. Feedback has been positive, with \noperations officers highlighting how the proposed solution addresses critical gaps in their current decision-\nmaking processes. Demonstrations of similar data integration challenges solved for complex commercial \nenterprises resonated strongly with Army stakeholders. The team’s proven track record in delivering secure \nenterprise transformations positions them to integrate their solutions with existing Army systems while driving \ninnovation across echelons and mission sets. \nThe Web3 Tech team possesses extensive experience and diverse skill sets, making them uniquely qualified \nto handle complex projects. Their proposed solution has significant commercial market potential, capable of \nenhancing operational efficiency and decision-making across various industries. The innovative approach \nmakes the solution a valuable asset for organizations and businesses seeking to optimize their data-driven \nprocesses and improve overall performance. The strategic growth target for the next three years includes \nprogressive revenue goals: Year 1 aims for $1M, representing a 3x growth; Year 2 targets $3.5M, which is 10x \nthe initial baseline; and Year 3 sets a goal of $12M, achieving 32x growth from the initial baseline. The following \nare some examples of this potential: \n1. Healthcare. The healthcare industry is ideal for this solution, enabling smooth integration with EHRs, \nmedical imaging, and operational systems to analyze patient  ...
#  Document(metadata={'producer': 'PCL2PDF (TM) from Visual Software', 'creator': '', 'creationdate': '2025-05-28T16:31:24+00:00', 'source': '../data/pdf/Transamerica_Policy_Issuance_158620564.pdf', 'file_path': '../data/pdf/Transamerica_Policy_Issuance_158620564.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': 'Converted from 158620564.pcl', 'author': 'Neil J. Geddes', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20250528163124+00'00'", 'page': 0}, page_content='08/01/2025\n08/01/2026\n05/28/2025\n24-MGU-25-A60481\n08/01/2025\nWorld Financial Group Inc.\nWorld Financial Group Insurance Agency, LLC\n6400 C Street SW\nCedar Rapids, IA 52499\nABHISHEK TRIPATHI\n1726 MAROON BELLS LANE\nBOLINGBROOK, IL, 60490'),
#  Document(metadata={'producer': 'PCL2PDF (TM) from Visual Software', 'creator': '', 'creationdate': '2025-05-28T16:31:24+00:00', 'source': '../data/pdf/Transamerica_Policy_Issuance_158620564.pdf', 'file_path': '../data/pdf/Transamerica_Policy_Issuance_158620564.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': 'Converted from 158620564.pcl', 'author': 'Neil J. Geddes', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20250528163124+00'00'", 'page': 1}, page_content='WFG-24-MGU-25-A60481\n08/01/2026')]

# %%
type(pdf_docuemnts[0])
# Out:
# langchain_core.documents.base.Document
